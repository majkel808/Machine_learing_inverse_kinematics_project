# %%
import matplotlib.pyplot as plt

#Data Manipulation
import pandas as pd
import numpy as np

# Machine Learning
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import Input, Dense, Dropout
import tensorflow as tf

df = pd.read_csv("collected_data_180_step_1.csv")

df_shuffled = df.sample(frac=1, random_state=42)
df = df_shuffled
print("From local")

df.head()


# Train test split
X_train_df, X_test_df = train_test_split(df, test_size=0.2, random_state=42)

# Train values
y1_train = np.array(X_train_df["Theta1"])
y2_train = np.array(X_train_df["Theta2"])
y3_train = np.array(X_train_df["Theta3"])

# Test values
y1_test = np.array(X_test_df["Theta1"])
y2_test = np.array(X_test_df["Theta2"])
y3_test = np.array(X_test_df["Theta3"])

# Remove the target values from the dataset
X_train_df = X_train_df.drop(["Theta1", "Theta2", "Theta3"], axis=1)
X_test_df = X_test_df.drop(["Theta1", "Theta2", "Theta3"], axis=1)

# Normalizing the dataset
X_train_norm = (X_train_df - X_train_df.mean()) / X_train_df.std()
X_test_norm = (X_test_df - X_test_df.mean()) / X_test_df.std()

# Convert to numpy arrays
X_train = X_train_norm.values
X_valid = X_test_norm.values

y1_train = y1_train.reshape(-1, 1) # Reshape y1_train to match X_train
y2_train = y2_train.reshape(-1, 1) # Reshape y2_train to match X_train
y3_train = y3_train.reshape(-1, 1) # Reshape y3_train to match X_train

y1_test = y1_test.reshape(-1, 1) # Reshape y1_train to match X_train
y2_test = y2_test.reshape(-1, 1) # Reshape y2_train to match X_train
y3_test = y3_test.reshape(-1, 1) # Reshape y2_train to match X_train

y_train = (y1_train, y2_train, y3_train)
y_valid = (y1_test, y2_test, y3_test)
# Out:
# From local

# %% [markdown]
# <h2 style="font-size: 20px;">CREATING THE MODEL</h2>

# %%
def train_model(X_train, y_train, X_valid, y_valid, input_nodes, hidden_nodes, hidden_nodes_2, output_nodes, learning_rate, batch_size, epochs, dropout_rate):
    """
    Train a neural network model for multi-output regression.

    Args:
    X_train (numpy.ndarray): Input features for training.
    y_train (tuple of numpy.ndarray): Target labels for training.
    X_valid (numpy.ndarray): Input features for validation.
    y_valid (tuple of numpy.ndarray): Target labels for validation.
    input_nodes (int): Number of nodes in the input layers of the neural network.
    hidden_nodes (int): Number of nodes in the first hidden layer of the neural network.
    hidden_nodes_2 (int): Number of nodes in the second hidden layer of the neural network.
    output_nodes (tuple of int): Number of nodes in the output layers of the neural network.
    learning_rate (float): Learning rate for the optimizer.
    batch_size (int): Number of samples per batch during training.
    epochs (int): Number of epochs for training.
    dropout_rate (float): Dropout rate for regularization.

    Returns:
    tuple: A tuple containing:
        - nn_model (keras.Model): Trained neural network model.
        - history (dict): Training history.
    """
    # Unpack target labels
    y1_train, y2_train, y3_train = y_train
    y1_valid, y2_valid, y3_valid = y_valid

    # Define input layer
    input_layer = Input(shape=(input_nodes,))

    # Define dense layers
    dense_layer_1 = Dense(units=hidden_nodes, activation="relu")(input_layer)
    dropout_layer_1 = Dropout(dropout_rate)(dense_layer_1)  # Adding dropout after the first dense layer

    
    dense_layer_2 = Dense(units=hidden_nodes, activation="relu")(dropout_layer_1)
    dropout_layer_2 = Dropout(dropout_rate)(dense_layer_2)  # Adding dropout after the second dense layer

    dense_layer_3 = Dense(units=hidden_nodes_2, activation="relu")(dropout_layer_2)
    
    dense_layer_4 = Dense(units=hidden_nodes_2, activation="relu")(dense_layer_3)
    dropout_layer_4 = Dropout(dropout_rate)(dense_layer_4)
    # Define Y1 output
    y1_output = Dense(units=1, activation="linear", name="y1_output")(dropout_layer_2)

    # Define Y2 output
    y2_output = Dense(units=1, activation="linear", name="y2_output")(dense_layer_3)

    # Define Y3 output
    y3_output = Dense(units=1, activation="linear", name="y3_output")(dropout_layer_4)

    # Define the model with the input layer and a list of outputs
    model = Model(inputs=input_layer, outputs=[y1_output, y2_output, y3_output])

    # Specify the optimizer
    optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)

    # Compile the model
    model.compile(optimizer=optimizer,
                  loss={'y1_output': 'mse', 'y2_output': 'mse', 'y3_output': 'mse'},
                  metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                           'y2_output': tf.keras.metrics.RootMeanSquaredError(),
                           'y3_output': tf.keras.metrics.RootMeanSquaredError()})

    # Train the model
    history = model.fit(X_train, {'y1_output': y1_train, 'y2_output': y2_train, 'y3_output': y3_train},
                        validation_data=(X_valid, {'y1_output': y1_valid, 'y2_output': y2_valid, 'y3_output': y3_valid}),
                        epochs=epochs, batch_size=batch_size, verbose=2)

    return model, history

import matplotlib.pyplot as plt

def plot_history(history):
    """
    Show the difference in loss and RMSE with each epoch of training the model.

    Args:
       history : Keras History object that stores information about the trained model.

    Returns:
        Plot showing the loss and RMSE with each epoch.
    """

    fig, axs = plt.subplots(3, 2, figsize=(20, 24))

    # Plot loss for y1
    axs[0, 0].plot(history.history['loss'], label='loss (y1)')
    axs[0, 0].plot(history.history['val_loss'], label='val_loss (y1)')
    axs[0, 0].set_xlabel('Epoch')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].grid(True)
    axs[0, 0].legend()

    # Plot RMSE for y1
    axs[0, 1].plot(history.history['y1_output_root_mean_squared_error'], label='RMSE (y1)')
    axs[0, 1].plot(history.history['val_y1_output_root_mean_squared_error'], label='val_RMSE (y1)')
    axs[0, 1].set_xlabel('Epoch')
    axs[0, 1].set_ylabel('RMSE')
    axs[0, 1].grid(True)
    axs[0, 1].legend()

    # Plot loss for y2
    axs[1, 0].plot(history.history['loss'], label='loss (y2)')
    axs[1, 0].plot(history.history['val_loss'], label='val_loss (y2)')
    axs[1, 0].set_xlabel('Epoch')
    axs[1, 0].set_ylabel('Loss')
    axs[1, 0].grid(True)
    axs[1, 0].legend()

    # Plot RMSE for y2
    axs[1, 1].plot(history.history['y2_output_root_mean_squared_error'], label='RMSE (y2)')
    axs[1, 1].plot(history.history['val_y2_output_root_mean_squared_error'], label='val_RMSE (y2)')
    axs[1, 1].set_xlabel('Epoch')
    axs[1, 1].set_ylabel('RMSE')
    axs[1, 1].grid(True)
    axs[1, 1].legend()

    # Plot loss for y3
    axs[2, 0].plot(history.history['loss'], label='loss (y3)')
    axs[2, 0].plot(history.history['val_loss'], label='val_loss (y3)')
    axs[2, 0].set_xlabel('Epoch')
    axs[2, 0].set_ylabel('Loss')
    axs[2, 0].grid(True)
    axs[2, 0].legend()

    # Plot RMSE for y3
    axs[2, 1].plot(history.history['y3_output_root_mean_squared_error'], label='RMSE (y3)')
    axs[2, 1].plot(history.history['val_y3_output_root_mean_squared_error'], label='val_RMSE (y3)')
    axs[2, 1].set_xlabel('Epoch')
    axs[2, 1].set_ylabel('RMSE')
    axs[2, 1].grid(True)
    axs[2, 1].legend()

    plt.show()

# %% [markdown]
# <h2 style="font-size: 20px;">PARAMETERS OF THE MODEL</h2>

# %%
input_nodes = len(X_train[1])
output_nodes = 1
epochs = 1000 #100 było git
hidden_nodes = 128  #60 było git
hidden_nodes_2 = 64  #64 było git
dropout_rate = 0.6
#0.25 było git
batch_size = 1000 #wczesniej 1000
learining_rate = 0.00001 #0.0001 było git

# %% [markdown]
# <h2 style="font-size: 20px;">TESTETING THE MODEL</h2>

# %%
model, history = train_model(X_train, y_train, X_valid, y_valid, input_nodes, hidden_nodes, hidden_nodes_2, output_nodes, learining_rate, batch_size, epochs, dropout_rate)
# Out:
# Epoch 1/1000
# 4666/4666 - 30s - loss: 7515.4482 - y1_output_loss: 3255.6013 - y2_output_loss: 2017.2113 - y3_output_loss: 2242.6218 - y1_output_root_mean_squared_error: 57.0579 - y2_output_root_mean_squared_error: 44.9134 - y3_output_root_mean_squared_error: 47.3563 - val_loss: 2665.1306 - val_y1_output_loss: 1697.1304 - val_y2_output_loss: 571.3690 - val_y3_output_loss: 396.6310 - val_y1_output_root_mean_squared_error: 41.1962 - val_y2_output_root_mean_squared_error: 23.9033 - val_y3_output_root_mean_squared_error: 19.9156 - 30s/epoch - 6ms/step
# Epoch 2/1000
# 4666/4666 - 28s - loss: 3568.4353 - y1_output_loss: 1995.2640 - y2_output_loss: 894.6461 - y3_output_loss: 678.5308 - y1_output_root_mean_squared_error: 44.6684 - y2_output_root_mean_squared_error: 29.9106 - y3_output_root_mean_squared_error: 26.0486 - val_loss: 2012.4554 - val_y1_output_loss: 1407.8939 - val_y2_output_loss: 405.2740 - val_y3_output_loss: 199.2876 - val_y1_output_root_mean_squared_error: 37.5219 - val_y2_output_root_mean_squared_error: 20.1314 - val_y3_output_root_mean_squared_error: 14.1169 - 28s/epoch - 6ms/step
# Epoch 3/1000
# 4666/4666 - 28s - loss: 3028.8542 - y1_output_loss: 1814.0665 - y2_output_loss: 719.2440 - y3_output_loss: 495.5440 - y1_output_root_mean_squared_error: 42.5919 - y2_output_root_mean_squared_error: 26.8187 - y3_output_root_mean_squared_error: 22.2608 - val_loss: 1806.1929 - val_y1_output_loss: 1294.1521 - val_y2_output_loss: 332.8591 - val_y3_output_loss: 179.1826 - val_y1_output_root_mean_squared_error: 35.9743 - val_y2_output_root_mean_squared_error: 18.2444 - val_y3_output_root_mean_squared_error: 13.3859 - 28s/epoch - 6ms/step
# Epoch 4/1000
# 4666/4666 - 28s - loss: 2759.5354 - y1_output_loss: 1719.3163 - y2_output_loss: 617.7377 - y3_output_loss: 422.4771 - y1_output_root_mean_squared_error: 41.4646 - y2_output_root_mean_squared_error: 24.8543 - y3_output_root_mean_squared_error: 20.5542 - val_loss: 1721.2885 - val_y1_output_loss: 1229.4365 - val_y2_output_loss: 291.7571 - val_y3_output_loss: 200.0942 - val_y1_output_root_mean_squared_error: 35.0633 - val_y2_output_root_mean_squared_error: 17.0809 - val_y3_output_root_mean_squared_error: 14.1455 - 28s/epoch - 6ms/step
# Epoch 5/1000
# 4666/4666 - 28s - loss: 2588.8682 - y1_output_loss: 1647.1791 - y2_output_loss: 553.6009 - y3_output_loss: 388.0902 - y1_output_root_mean_squared_error: 40.5855 - y2_output_root_mean_squared_error: 23.5287 - y3_output_root_mean_squared_error: 19.7000 - val_loss: 1662.5425 - val_y1_output_loss: 1175.9283 - val_y2_output_loss: 270.8791 - val_y3_output_loss: 215.7344 - val_y1_output_root_mean_squared_error: 34.2918 - val_y2_output_root_mean_squared_error: 16.4584 - val_y3_output_root_mean_squared_error: 14.6879 - 28s/epoch - 6ms/step
# Epoch 6/1000
# 4666/4666 - 28s - loss: 2459.9514 - y1_output_loss: 1586.6154 - y2_output_loss: 507.1439 - y3_output_loss: 366.1907 - y1_output_root_mean_squared_error: 39.8323 - y2_output_root_mean_squared_error: 22.5199 - y3_output_root_mean_squared_error: 19.1361 - val_loss: 1645.7659 - val_y1_output_loss: 1123.8979 - val_y2_output_loss: 257.8944 - val_y3_output_loss: 263.9740 - val_y1_output_root_mean_squared_error: 33.5246 - val_y2_output_root_mean_squared_error: 16.0591 - val_y3_output_root_mean_squared_error: 16.2473 - 28s/epoch - 6ms/step
# Epoch 7/1000
# 4666/4666 - 28s - loss: 2356.1401 - y1_output_loss: 1531.6600 - y2_output_loss: 474.6454 - y3_output_loss: 349.8360 - y1_output_root_mean_squared_error: 39.1364 - y2_output_root_mean_squared_error: 21.7864 - y3_output_root_mean_squared_error: 18.7039 - val_loss: 1608.5883 - val_y1_output_loss: 1075.0096 - val_y2_output_loss: 246.8074 - val_y3_output_loss: 286.7718 - val_y1_output_root_mean_squared_error: 32.7873 - val_y2_output_root_mean_squared_error: 15.7101 - val_y3_output_root_mean_squared_error: 16.9343 - 28s/epoch - 6ms/step
# Epoch 8/1000
# 4666/4666 - 28s - loss: 2268.9932 - y1_output_loss: 1485.3639 - y2_output_loss: 447.4786 - y3_output_loss: 336.1509 - y1_output_root_mean_squared_error: 38.5404 - y2_output_root_mean_squared_error: 21.1537 - y3_output_root_mean_squared_error: 18.3344 - val_loss: 1599.2849 - val_y1_output_loss: 1038.1073 - val_y2_output_loss: 237.3047 - val_y3_output_loss: 323.8749 - val_y1_output_root_mean_squared_error: 32.2197 - val_y2_output_root_mean_squared_error: 15.4047 - val_y3_output_root_mean_squared_error: 17.9965 - 28s/epoch - 6ms/step
# Epoch 9/1000
# 4666/4666 - 28s - loss: 2190.6738 - y1_output_loss: 1440.1798 - y2_output_loss: 424.4528 - y3_output_loss: 326.0419 - y1_output_root_mean_squared_error: 37.9497 - y2_output_root_mean_squared_error: 20.6023 - y3_output_root_mean_squared_error: 18.0566 - val_loss: 1561.2345 - val_y1_output_loss: 989.1437 - val_y2_output_loss: 231.8053 - val_y3_output_loss: 340.2850 - val_y1_output_root_mean_squared_error: 31.4507 - val_y2_output_root_mean_squared_error: 15.2252 - val_y3_output_root_mean_squared_error: 18.4468 - 28s/epoch - 6ms/step
# Epoch 10/1000
# 4666/4666 - 28s - loss: 2117.8357 - y1_output_loss: 1396.2483 - y2_output_loss: 403.8405 - y3_output_loss: 317.7493 - y1_output_root_mean_squared_error: 37.3664 - y2_output_root_mean_squared_error: 20.0958 - y3_output_root_mean_squared_error: 17.8255 - val_loss: 1578.2422 - val_y1_output_loss: 949.7383 - val_y2_output_loss: 225.3305 - val_y3_output_loss: 403.1714 - val_y1_output_root_mean_squared_error: 30.8178 - val_y2_output_root_mean_squared_error: 15.0110 - val_y3_output_root_mean_squared_error: 20.0791 - 28s/epoch - 6ms/step
# Epoch 11/1000
# 4666/4666 - 28s - loss: 2050.3271 - y1_output_loss: 1353.3724 - y2_output_loss: 386.2871 - y3_output_loss: 310.6625 - y1_output_root_mean_squared_error: 36.7882 - y2_output_root_mean_squared_error: 19.6542 - y3_output_root_mean_squared_error: 17.6256 - val_loss: 1599.1863 - val_y1_output_loss: 914.6096 - val_y2_output_loss: 225.3311 - val_y3_output_loss: 459.2441 - val_y1_output_root_mean_squared_error: 30.2425 - val_y2_output_root_mean_squared_error: 15.0110 - val_y3_output_root_mean_squared_error: 21.4300 - 28s/epoch - 6ms/step
# Epoch 12/1000
# 4666/4666 - 27s - loss: 1988.3540 - y1_output_loss: 1315.3920 - y2_output_loss: 368.7423 - y3_output_loss: 304.2197 - y1_output_root_mean_squared_error: 36.2683 - y2_output_root_mean_squared_error: 19.2027 - y3_output_root_mean_squared_error: 17.4419 - val_loss: 1632.7383 - val_y1_output_loss: 880.2385 - val_y2_output_loss: 223.1880 - val_y3_output_loss: 529.3115 - val_y1_output_root_mean_squared_error: 29.6688 - val_y2_output_root_mean_squared_error: 14.9395 - val_y3_output_root_mean_squared_error: 23.0068 - 27s/epoch - 6ms/step
# Epoch 13/1000
# 4666/4666 - 27s - loss: 1930.6556 - y1_output_loss: 1280.2825 - y2_output_loss: 352.4102 - y3_output_loss: 297.9634 - y1_output_root_mean_squared_error: 35.7810 - y2_output_root_mean_squared_error: 18.7726 - y3_output_root_mean_squared_error: 17.2616 - val_loss: 1670.7701 - val_y1_output_loss: 839.9192 - val_y2_output_loss: 232.5643 - val_y3_output_loss: 598.2859 - val_y1_output_root_mean_squared_error: 28.9814 - val_y2_output_root_mean_squared_error: 15.2501 - val_y3_output_root_mean_squared_error: 24.4599 - 27s/epoch - 6ms/step
# Epoch 14/1000
# 4666/4666 - 28s - loss: 1877.7853 - y1_output_loss: 1248.0962 - y2_output_loss: 338.1922 - y3_output_loss: 291.4977 - y1_output_root_mean_squared_error: 35.3284 - y2_output_root_mean_squared_error: 18.3900 - y3_output_root_mean_squared_error: 17.0733 - val_loss: 1691.4441 - val_y1_output_loss: 816.3519 - val_y2_output_loss: 240.9004 - val_y3_output_loss: 634.1936 - val_y1_output_root_mean_squared_error: 28.5719 - val_y2_output_root_mean_squared_error: 15.5210 - val_y3_output_root_mean_squared_error: 25.1832 - 28s/epoch - 6ms/step
# Epoch 15/1000
# 4666/4666 - 28s - loss: 1830.9817 - y1_output_loss: 1220.7806 - y2_output_loss: 324.7871 - y3_output_loss: 285.4138 - y1_output_root_mean_squared_error: 34.9397 - y2_output_root_mean_squared_error: 18.0219 - y3_output_root_mean_squared_error: 16.8942 - val_loss: 1733.9381 - val_y1_output_loss: 790.9932 - val_y2_output_loss: 251.0293 - val_y3_output_loss: 691.9160 - val_y1_output_root_mean_squared_error: 28.1246 - val_y2_output_root_mean_squared_error: 15.8439 - val_y3_output_root_mean_squared_error: 26.3043 - 28s/epoch - 6ms/step
# Epoch 16/1000
# 4666/4666 - 29s - loss: 1787.5767 - y1_output_loss: 1194.5361 - y2_output_loss: 313.5137 - y3_output_loss: 279.5240 - y1_output_root_mean_squared_error: 34.5621 - y2_output_root_mean_squared_error: 17.7063 - y3_output_root_mean_squared_error: 16.7190 - val_loss: 1763.2037 - val_y1_output_loss: 767.3496 - val_y2_output_loss: 265.3348 - val_y3_output_loss: 730.5192 - val_y1_output_root_mean_squared_error: 27.7011 - val_y2_output_root_mean_squared_error: 16.2891 - val_y3_output_root_mean_squared_error: 27.0281 - 29s/epoch - 6ms/step
# Epoch 17/1000
# 4666/4666 - 28s - loss: 1750.8715 - y1_output_loss: 1173.0380 - y2_output_loss: 303.7588 - y3_output_loss: 274.0767 - y1_output_root_mean_squared_error: 34.2496 - y2_output_root_mean_squared_error: 17.4287 - y3_output_root_mean_squared_error: 16.5553 - val_loss: 1746.5674 - val_y1_output_loss: 749.4644 - val_y2_output_loss: 275.4807 - val_y3_output_loss: 721.6216 - val_y1_output_root_mean_squared_error: 27.3763 - val_y2_output_root_mean_squared_error: 16.5976 - val_y3_output_root_mean_squared_error: 26.8630 - 28s/epoch - 6ms/step
# Epoch 18/1000
# 4666/4666 - 28s - loss: 1713.8315 - y1_output_loss: 1151.7837 - y2_output_loss: 293.3070 - y3_output_loss: 268.7411 - y1_output_root_mean_squared_error: 33.9379 - y2_output_root_mean_squared_error: 17.1262 - y3_output_root_mean_squared_error: 16.3933 - val_loss: 1752.8997 - val_y1_output_loss: 733.3351 - val_y2_output_loss: 292.5501 - val_y3_output_loss: 727.0142 - val_y1_output_root_mean_squared_error: 27.0802 - val_y2_output_root_mean_squared_error: 17.1041 - val_y3_output_root_mean_squared_error: 26.9632 - 28s/epoch - 6ms/step
# Epoch 19/1000
# 4666/4666 - 29s - loss: 1681.4856 - y1_output_loss: 1132.8052 - y2_output_loss: 285.1634 - y3_output_loss: 263.5130 - y1_output_root_mean_squared_error: 33.6572 - y2_output_root_mean_squared_error: 16.8868 - y3_output_root_mean_squared_error: 16.2331 - val_loss: 1764.9556 - val_y1_output_loss: 715.6309 - val_y2_output_loss: 306.3934 - val_y3_output_loss: 742.9307 - val_y1_output_root_mean_squared_error: 26.7513 - val_y2_output_root_mean_squared_error: 17.5041 - val_y3_output_root_mean_squared_error: 27.2568 - 29s/epoch - 6ms/step
# Epoch 20/1000
# 4666/4666 - 28s - loss: 1649.6881 - y1_output_loss: 1113.8850 - y2_output_loss: 277.0895 - y3_output_loss: 258.7094 - y1_output_root_mean_squared_error: 33.3749 - y2_output_root_mean_squared_error: 16.6460 - y3_output_root_mean_squared_error: 16.0844 - val_loss: 1706.7505 - val_y1_output_loss: 697.4091 - val_y2_output_loss: 314.0594 - val_y3_output_loss: 695.2830 - val_y1_output_root_mean_squared_error: 26.4085 - val_y2_output_root_mean_squared_error: 17.7217 - val_y3_output_root_mean_squared_error: 26.3682 - 28s/epoch - 6ms/step
# Epoch 21/1000
# 4666/4666 - 28s - loss: 1621.7263 - y1_output_loss: 1098.0255 - y2_output_loss: 269.5036 - y3_output_loss: 254.1940 - y1_output_root_mean_squared_error: 33.1365 - y2_output_root_mean_squared_error: 16.4166 - y3_output_root_mean_squared_error: 15.9435 - val_loss: 1729.0901 - val_y1_output_loss: 692.5123 - val_y2_output_loss: 321.0139 - val_y3_output_loss: 715.5643 - val_y1_output_root_mean_squared_error: 26.3156 - val_y2_output_root_mean_squared_error: 17.9169 - val_y3_output_root_mean_squared_error: 26.7500 - 28s/epoch - 6ms/step
# Epoch 22/1000
# 4666/4666 - 31s - loss: 1593.9415 - y1_output_loss: 1081.4813 - y2_output_loss: 261.8958 - y3_output_loss: 250.5675 - y1_output_root_mean_squared_error: 32.8859 - y2_output_root_mean_squared_error: 16.1832 - y3_output_root_mean_squared_error: 15.8293 - val_loss: 1777.5750 - val_y1_output_loss: 676.7148 - val_y2_output_loss: 335.8670 - val_y3_output_loss: 764.9927 - val_y1_output_root_mean_squared_error: 26.0137 - val_y2_output_root_mean_squared_error: 18.3267 - val_y3_output_root_mean_squared_error: 27.6585 - 31s/epoch - 7ms/step
# Epoch 23/1000
# 4666/4666 - 31s - loss: 1571.5729 - y1_output_loss: 1069.4878 - y2_output_loss: 255.3523 - y3_output_loss: 246.7357 - y1_output_root_mean_squared_error: 32.7030 - y2_output_root_mean_squared_error: 15.9797 - y3_output_root_mean_squared_error: 15.7078 - val_loss: 1745.8890 - val_y1_output_loss: 664.3716 - val_y2_output_loss: 344.6414 - val_y3_output_loss: 736.8755 - val_y1_output_root_mean_squared_error: 25.7754 - val_y2_output_root_mean_squared_error: 18.5645 - val_y3_output_root_mean_squared_error: 27.1455 - 31s/epoch - 7ms/step
# Epoch 24/1000
# 4666/4666 - 32s - loss: 1548.5122 - y1_output_loss: 1055.5033 - y2_output_loss: 249.1601 - y3_output_loss: 243.8513 - y1_output_root_mean_squared_error: 32.4885 - y2_output_root_mean_squared_error: 15.7848 - y3_output_root_mean_squared_error: 15.6157 - val_loss: 1680.2172 - val_y1_output_loss: 653.3782 - val_y2_output_loss: 361.1953 - val_y3_output_loss: 665.6425 - val_y1_output_root_mean_squared_error: 25.5613 - val_y2_output_root_mean_squared_error: 19.0051 - val_y3_output_root_mean_squared_error: 25.8000 - 32s/epoch - 7ms/step
# Epoch 25/1000
# 4666/4666 - 30s - loss: 1528.7013 - y1_output_loss: 1043.1674 - y2_output_loss: 244.3067 - y3_output_loss: 241.2293 - y1_output_root_mean_squared_error: 32.2981 - y2_output_root_mean_squared_error: 15.6303 - y3_output_root_mean_squared_error: 15.5316 - val_loss: 1761.2404 - val_y1_output_loss: 645.3135 - val_y2_output_loss: 365.5085 - val_y3_output_loss: 750.4205 - val_y1_output_root_mean_squared_error: 25.4030 - val_y2_output_root_mean_squared_error: 19.1183 - val_y3_output_root_mean_squared_error: 27.3938 - 30s/epoch - 6ms/step
# Epoch 26/1000
# 4666/4666 - 31s - loss: 1508.8479 - y1_output_loss: 1030.4377 - y2_output_loss: 239.7910 - y3_output_loss: 238.6181 - y1_output_root_mean_squared_error: 32.1004 - y2_output_root_mean_squared_error: 15.4852 - y3_output_root_mean_squared_error: 15.4473 - val_loss: 1722.6826 - val_y1_output_loss: 633.3517 - val_y2_output_loss: 370.0126 - val_y3_output_loss: 719.3186 - val_y1_output_root_mean_squared_error: 25.1665 - val_y2_output_root_mean_squared_error: 19.2357 - val_y3_output_root_mean_squared_error: 26.8201 - 31s/epoch - 7ms/step
# Epoch 27/1000
# 4666/4666 - 30s - loss: 1491.2075 - y1_output_loss: 1020.0878 - y2_output_loss: 235.2072 - y3_output_loss: 235.9148 - y1_output_root_mean_squared_error: 31.9388 - y2_output_root_mean_squared_error: 15.3365 - y3_output_root_mean_squared_error: 15.3595 - val_loss: 1741.0800 - val_y1_output_loss: 630.2827 - val_y2_output_loss: 387.0859 - val_y3_output_loss: 723.7102 - val_y1_output_root_mean_squared_error: 25.1054 - val_y2_output_root_mean_squared_error: 19.6745 - val_y3_output_root_mean_squared_error: 26.9019 - 30s/epoch - 7ms/step
# Epoch 28/1000
# 4666/4666 - 31s - loss: 1474.7029 - y1_output_loss: 1010.1667 - y2_output_loss: 231.0937 - y3_output_loss: 233.4409 - y1_output_root_mean_squared_error: 31.7831 - y2_output_root_mean_squared_error: 15.2018 - y3_output_root_mean_squared_error: 15.2788 - val_loss: 1817.7965 - val_y1_output_loss: 620.8766 - val_y2_output_loss: 380.6692 - val_y3_output_loss: 816.2523 - val_y1_output_root_mean_squared_error: 24.9174 - val_y2_output_root_mean_squared_error: 19.5107 - val_y3_output_root_mean_squared_error: 28.5701 - 31s/epoch - 7ms/step
# Epoch 29/1000
# 4666/4666 - 32s - loss: 1459.0833 - y1_output_loss: 1000.5141 - y2_output_loss: 227.5128 - y3_output_loss: 231.0539 - y1_output_root_mean_squared_error: 31.6309 - y2_output_root_mean_squared_error: 15.0835 - y3_output_root_mean_squared_error: 15.2005 - val_loss: 1754.2930 - val_y1_output_loss: 608.3563 - val_y2_output_loss: 382.3286 - val_y3_output_loss: 763.6086 - val_y1_output_root_mean_squared_error: 24.6649 - val_y2_output_root_mean_squared_error: 19.5532 - val_y3_output_root_mean_squared_error: 27.6335 - 32s/epoch - 7ms/step
# Epoch 30/1000
# 4666/4666 - 29s - loss: 1444.0690 - y1_output_loss: 991.1299 - y2_output_loss: 223.4686 - y3_output_loss: 229.4743 - y1_output_root_mean_squared_error: 31.4822 - y2_output_root_mean_squared_error: 14.9489 - y3_output_root_mean_squared_error: 15.1484 - val_loss: 1740.0548 - val_y1_output_loss: 605.0969 - val_y2_output_loss: 379.1421 - val_y3_output_loss: 755.8168 - val_y1_output_root_mean_squared_error: 24.5987 - val_y2_output_root_mean_squared_error: 19.4716 - val_y3_output_root_mean_squared_error: 27.4921 - 29s/epoch - 6ms/step
# Epoch 31/1000
# 4666/4666 - 31s - loss: 1431.2419 - y1_output_loss: 982.9348 - y2_output_loss: 220.6860 - y3_output_loss: 227.6227 - y1_output_root_mean_squared_error: 31.3518 - y2_output_root_mean_squared_error: 14.8555 - y3_output_root_mean_squared_error: 15.0872 - val_loss: 1741.3824 - val_y1_output_loss: 597.2664 - val_y2_output_loss: 389.8722 - val_y3_output_loss: 754.2442 - val_y1_output_root_mean_squared_error: 24.4390 - val_y2_output_root_mean_squared_error: 19.7452 - val_y3_output_root_mean_squared_error: 27.4635 - 31s/epoch - 7ms/step
# Epoch 32/1000
# 4666/4666 - 31s - loss: 1418.6729 - y1_output_loss: 976.0044 - y2_output_loss: 217.2368 - y3_output_loss: 225.4295 - y1_output_root_mean_squared_error: 31.2411 - y2_output_root_mean_squared_error: 14.7390 - y3_output_root_mean_squared_error: 15.0143 - val_loss: 1780.3080 - val_y1_output_loss: 589.3832 - val_y2_output_loss: 379.3181 - val_y3_output_loss: 811.6054 - val_y1_output_root_mean_squared_error: 24.2772 - val_y2_output_root_mean_squared_error: 19.4761 - val_y3_output_root_mean_squared_error: 28.4887 - 31s/epoch - 7ms/step
# Epoch 33/1000
# 4666/4666 - 30s - loss: 1406.6556 - y1_output_loss: 968.3073 - y2_output_loss: 214.4040 - y3_output_loss: 223.9446 - y1_output_root_mean_squared_error: 31.1176 - y2_output_root_mean_squared_error: 14.6425 - y3_output_root_mean_squared_error: 14.9648 - val_loss: 1701.3143 - val_y1_output_loss: 581.6946 - val_y2_output_loss: 384.2018 - val_y3_output_loss: 735.4178 - val_y1_output_root_mean_squared_error: 24.1183 - val_y2_output_root_mean_squared_error: 19.6011 - val_y3_output_root_mean_squared_error: 27.1186 - 30s/epoch - 7ms/step
# Epoch 34/1000
# 4666/4666 - 29s - loss: 1394.6433 - y1_output_loss: 960.2189 - y2_output_loss: 211.9887 - y3_output_loss: 222.4337 - y1_output_root_mean_squared_error: 30.9874 - y2_output_root_mean_squared_error: 14.5598 - y3_output_root_mean_squared_error: 14.9142 - val_loss: 1783.7263 - val_y1_output_loss: 576.9963 - val_y2_output_loss: 370.5841 - val_y3_output_loss: 836.1462 - val_y1_output_root_mean_squared_error: 24.0207 - val_y2_output_root_mean_squared_error: 19.2506 - val_y3_output_root_mean_squared_error: 28.9162 - 29s/epoch - 6ms/step
# Epoch 35/1000
# 4666/4666 - 30s - loss: 1382.8479 - y1_output_loss: 952.6945 - y2_output_loss: 209.3892 - y3_output_loss: 220.7657 - y1_output_root_mean_squared_error: 30.8657 - y2_output_root_mean_squared_error: 14.4703 - y3_output_root_mean_squared_error: 14.8582 - val_loss: 1833.3507 - val_y1_output_loss: 573.4978 - val_y2_output_loss: 366.9887 - val_y3_output_loss: 892.8654 - val_y1_output_root_mean_squared_error: 23.9478 - val_y2_output_root_mean_squared_error: 19.1569 - val_y3_output_root_mean_squared_error: 29.8809 - 30s/epoch - 6ms/step
# Epoch 36/1000
# 4666/4666 - 28s - loss: 1372.1875 - y1_output_loss: 945.7961 - y2_output_loss: 207.0152 - y3_output_loss: 219.3773 - y1_output_root_mean_squared_error: 30.7538 - y2_output_root_mean_squared_error: 14.3880 - y3_output_root_mean_squared_error: 14.8114 - val_loss: 1684.6562 - val_y1_output_loss: 565.4238 - val_y2_output_loss: 356.1687 - val_y3_output_loss: 763.0632 - val_y1_output_root_mean_squared_error: 23.7786 - val_y2_output_root_mean_squared_error: 18.8724 - val_y3_output_root_mean_squared_error: 27.6236 - 28s/epoch - 6ms/step
# Epoch 37/1000
# 4666/4666 - 26s - loss: 1362.0514 - y1_output_loss: 939.1547 - y2_output_loss: 204.4198 - y3_output_loss: 218.4758 - y1_output_root_mean_squared_error: 30.6456 - y2_output_root_mean_squared_error: 14.2975 - y3_output_root_mean_squared_error: 14.7809 - val_loss: 1840.8683 - val_y1_output_loss: 570.1412 - val_y2_output_loss: 368.1263 - val_y3_output_loss: 902.6011 - val_y1_output_root_mean_squared_error: 23.8776 - val_y2_output_root_mean_squared_error: 19.1866 - val_y3_output_root_mean_squared_error: 30.0433 - 26s/epoch - 6ms/step
# Epoch 38/1000
# 4666/4666 - 26s - loss: 1352.7969 - y1_output_loss: 933.1692 - y2_output_loss: 202.6435 - y3_output_loss: 216.9837 - y1_output_root_mean_squared_error: 30.5478 - y2_output_root_mean_squared_error: 14.2353 - y3_output_root_mean_squared_error: 14.7304 - val_loss: 1853.9017 - val_y1_output_loss: 563.7939 - val_y2_output_loss: 364.0294 - val_y3_output_loss: 926.0795 - val_y1_output_root_mean_squared_error: 23.7443 - val_y2_output_root_mean_squared_error: 19.0796 - val_y3_output_root_mean_squared_error: 30.4316 - 26s/epoch - 6ms/step
# Epoch 39/1000
# 4666/4666 - 26s - loss: 1344.0527 - y1_output_loss: 927.9201 - y2_output_loss: 200.5149 - y3_output_loss: 215.6160 - y1_output_root_mean_squared_error: 30.4618 - y2_output_root_mean_squared_error: 14.1603 - y3_output_root_mean_squared_error: 14.6839 - val_loss: 1745.0371 - val_y1_output_loss: 554.7829 - val_y2_output_loss: 348.5501 - val_y3_output_loss: 841.7031 - val_y1_output_root_mean_squared_error: 23.5538 - val_y2_output_root_mean_squared_error: 18.6695 - val_y3_output_root_mean_squared_error: 29.0121 - 26s/epoch - 6ms/step
# Epoch 40/1000
# 4666/4666 - 27s - loss: 1335.1270 - y1_output_loss: 920.8795 - y2_output_loss: 198.8430 - y3_output_loss: 215.4042 - y1_output_root_mean_squared_error: 30.3460 - y2_output_root_mean_squared_error: 14.1012 - y3_output_root_mean_squared_error: 14.6767 - val_loss: 1788.9789 - val_y1_output_loss: 548.1821 - val_y2_output_loss: 345.2593 - val_y3_output_loss: 895.5385 - val_y1_output_root_mean_squared_error: 23.4133 - val_y2_output_root_mean_squared_error: 18.5812 - val_y3_output_root_mean_squared_error: 29.9255 - 27s/epoch - 6ms/step
# Epoch 41/1000
# 4666/4666 - 27s - loss: 1326.4307 - y1_output_loss: 915.6251 - y2_output_loss: 196.9536 - y3_output_loss: 213.8527 - y1_output_root_mean_squared_error: 30.2593 - y2_output_root_mean_squared_error: 14.0340 - y3_output_root_mean_squared_error: 14.6237 - val_loss: 1811.5183 - val_y1_output_loss: 541.7336 - val_y2_output_loss: 331.7562 - val_y3_output_loss: 938.0278 - val_y1_output_root_mean_squared_error: 23.2752 - val_y2_output_root_mean_squared_error: 18.2142 - val_y3_output_root_mean_squared_error: 30.6272 - 27s/epoch - 6ms/step
# Epoch 42/1000
# 4666/4666 - 27s - loss: 1318.7122 - y1_output_loss: 910.1259 - y2_output_loss: 195.4519 - y3_output_loss: 213.1338 - y1_output_root_mean_squared_error: 30.1683 - y2_output_root_mean_squared_error: 13.9804 - y3_output_root_mean_squared_error: 14.5991 - val_loss: 1690.3479 - val_y1_output_loss: 538.4730 - val_y2_output_loss: 333.0913 - val_y3_output_loss: 818.7828 - val_y1_output_root_mean_squared_error: 23.2050 - val_y2_output_root_mean_squared_error: 18.2508 - val_y3_output_root_mean_squared_error: 28.6144 - 27s/epoch - 6ms/step
# Epoch 43/1000
# 4666/4666 - 26s - loss: 1311.1256 - y1_output_loss: 904.6661 - y2_output_loss: 193.8007 - y3_output_loss: 212.6585 - y1_output_root_mean_squared_error: 30.0777 - y2_output_root_mean_squared_error: 13.9212 - y3_output_root_mean_squared_error: 14.5828 - val_loss: 1668.3331 - val_y1_output_loss: 536.8417 - val_y2_output_loss: 319.7703 - val_y3_output_loss: 811.7216 - val_y1_output_root_mean_squared_error: 23.1698 - val_y2_output_root_mean_squared_error: 17.8821 - val_y3_output_root_mean_squared_error: 28.4907 - 26s/epoch - 6ms/step
# Epoch 44/1000
# 4666/4666 - 27s - loss: 1304.5658 - y1_output_loss: 900.4783 - y2_output_loss: 192.2737 - y3_output_loss: 211.8145 - y1_output_root_mean_squared_error: 30.0080 - y2_output_root_mean_squared_error: 13.8663 - y3_output_root_mean_squared_error: 14.5538 - val_loss: 1713.4089 - val_y1_output_loss: 530.6808 - val_y2_output_loss: 324.6929 - val_y3_output_loss: 858.0356 - val_y1_output_root_mean_squared_error: 23.0365 - val_y2_output_root_mean_squared_error: 18.0192 - val_y3_output_root_mean_squared_error: 29.2922 - 27s/epoch - 6ms/step
# Epoch 45/1000
# 4666/4666 - 27s - loss: 1296.0901 - y1_output_loss: 894.4689 - y2_output_loss: 190.8573 - y3_output_loss: 210.7633 - y1_output_root_mean_squared_error: 29.9077 - y2_output_root_mean_squared_error: 13.8151 - y3_output_root_mean_squared_error: 14.5177 - val_loss: 1771.0905 - val_y1_output_loss: 527.3260 - val_y2_output_loss: 304.4082 - val_y3_output_loss: 939.3568 - val_y1_output_root_mean_squared_error: 22.9636 - val_y2_output_root_mean_squared_error: 17.4473 - val_y3_output_root_mean_squared_error: 30.6489 - 27s/epoch - 6ms/step
# Epoch 46/1000
# 4666/4666 - 27s - loss: 1289.0381 - y1_output_loss: 889.4084 - y2_output_loss: 189.4047 - y3_output_loss: 210.2210 - y1_output_root_mean_squared_error: 29.8230 - y2_output_root_mean_squared_error: 13.7624 - y3_output_root_mean_squared_error: 14.4990 - val_loss: 1724.8145 - val_y1_output_loss: 523.8945 - val_y2_output_loss: 309.2820 - val_y3_output_loss: 891.6385 - val_y1_output_root_mean_squared_error: 22.8887 - val_y2_output_root_mean_squared_error: 17.5864 - val_y3_output_root_mean_squared_error: 29.8603 - 27s/epoch - 6ms/step
# Epoch 47/1000
# 4666/4666 - 27s - loss: 1281.4042 - y1_output_loss: 883.7651 - y2_output_loss: 187.9607 - y3_output_loss: 209.6796 - y1_output_root_mean_squared_error: 29.7282 - y2_output_root_mean_squared_error: 13.7099 - y3_output_root_mean_squared_error: 14.4803 - val_loss: 1629.9701 - val_y1_output_loss: 518.8944 - val_y2_output_loss: 305.0382 - val_y3_output_loss: 806.0372 - val_y1_output_root_mean_squared_error: 22.7793 - val_y2_output_root_mean_squared_error: 17.4653 - val_y3_output_root_mean_squared_error: 28.3908 - 27s/epoch - 6ms/step
# Epoch 48/1000
# 4666/4666 - 27s - loss: 1275.4871 - y1_output_loss: 879.3936 - y2_output_loss: 186.8451 - y3_output_loss: 209.2481 - y1_output_root_mean_squared_error: 29.6546 - y2_output_root_mean_squared_error: 13.6691 - y3_output_root_mean_squared_error: 14.4654 - val_loss: 1673.8984 - val_y1_output_loss: 515.3850 - val_y2_output_loss: 297.7266 - val_y3_output_loss: 860.7868 - val_y1_output_root_mean_squared_error: 22.7021 - val_y2_output_root_mean_squared_error: 17.2548 - val_y3_output_root_mean_squared_error: 29.3392 - 27s/epoch - 6ms/step
# Epoch 49/1000
# 4666/4666 - 27s - loss: 1269.7865 - y1_output_loss: 875.8979 - y2_output_loss: 185.7048 - y3_output_loss: 208.1829 - y1_output_root_mean_squared_error: 29.5956 - y2_output_root_mean_squared_error: 13.6274 - y3_output_root_mean_squared_error: 14.4285 - val_loss: 1857.0546 - val_y1_output_loss: 509.5133 - val_y2_output_loss: 295.5441 - val_y3_output_loss: 1051.9966 - val_y1_output_root_mean_squared_error: 22.5724 - val_y2_output_root_mean_squared_error: 17.1914 - val_y3_output_root_mean_squared_error: 32.4345 - 27s/epoch - 6ms/step
# Epoch 50/1000
# 4666/4666 - 26s - loss: 1262.6404 - y1_output_loss: 870.2635 - y2_output_loss: 184.2582 - y3_output_loss: 208.1212 - y1_output_root_mean_squared_error: 29.5002 - y2_output_root_mean_squared_error: 13.5742 - y3_output_root_mean_squared_error: 14.4264 - val_loss: 1837.4432 - val_y1_output_loss: 509.8474 - val_y2_output_loss: 287.6202 - val_y3_output_loss: 1039.9788 - val_y1_output_root_mean_squared_error: 22.5798 - val_y2_output_root_mean_squared_error: 16.9594 - val_y3_output_root_mean_squared_error: 32.2487 - 26s/epoch - 6ms/step
# Epoch 51/1000
# 4666/4666 - 27s - loss: 1256.1261 - y1_output_loss: 866.2415 - y2_output_loss: 182.9998 - y3_output_loss: 206.8846 - y1_output_root_mean_squared_error: 29.4320 - y2_output_root_mean_squared_error: 13.5277 - y3_output_root_mean_squared_error: 14.3835 - val_loss: 1738.8781 - val_y1_output_loss: 500.2080 - val_y2_output_loss: 283.1157 - val_y3_output_loss: 955.5540 - val_y1_output_root_mean_squared_error: 22.3653 - val_y2_output_root_mean_squared_error: 16.8260 - val_y3_output_root_mean_squared_error: 30.9120 - 27s/epoch - 6ms/step
# Epoch 52/1000
# 4666/4666 - 27s - loss: 1249.6522 - y1_output_loss: 861.2737 - y2_output_loss: 181.7480 - y3_output_loss: 206.6281 - y1_output_root_mean_squared_error: 29.3475 - y2_output_root_mean_squared_error: 13.4814 - y3_output_root_mean_squared_error: 14.3746 - val_loss: 1737.6095 - val_y1_output_loss: 496.7943 - val_y2_output_loss: 276.6853 - val_y3_output_loss: 964.1286 - val_y1_output_root_mean_squared_error: 22.2889 - val_y2_output_root_mean_squared_error: 16.6339 - val_y3_output_root_mean_squared_error: 31.0504 - 27s/epoch - 6ms/step
# Epoch 53/1000
# 4666/4666 - 27s - loss: 1244.4352 - y1_output_loss: 857.5200 - y2_output_loss: 180.9508 - y3_output_loss: 205.9664 - y1_output_root_mean_squared_error: 29.2834 - y2_output_root_mean_squared_error: 13.4518 - y3_output_root_mean_squared_error: 14.3515 - val_loss: 1650.9333 - val_y1_output_loss: 496.4515 - val_y2_output_loss: 280.0338 - val_y3_output_loss: 874.4500 - val_y1_output_root_mean_squared_error: 22.2812 - val_y2_output_root_mean_squared_error: 16.7342 - val_y3_output_root_mean_squared_error: 29.5711 - 27s/epoch - 6ms/step
# Epoch 54/1000
# 4666/4666 - 28s - loss: 1238.7078 - y1_output_loss: 852.7355 - y2_output_loss: 180.2343 - y3_output_loss: 205.7392 - y1_output_root_mean_squared_error: 29.2016 - y2_output_root_mean_squared_error: 13.4251 - y3_output_root_mean_squared_error: 14.3436 - val_loss: 1732.5977 - val_y1_output_loss: 487.6974 - val_y2_output_loss: 270.5864 - val_y3_output_loss: 974.3126 - val_y1_output_root_mean_squared_error: 22.0839 - val_y2_output_root_mean_squared_error: 16.4495 - val_y3_output_root_mean_squared_error: 31.2140 - 28s/epoch - 6ms/step
# Epoch 55/1000
# 4666/4666 - 26s - loss: 1232.5311 - y1_output_loss: 848.3348 - y2_output_loss: 178.8634 - y3_output_loss: 205.3340 - y1_output_root_mean_squared_error: 29.1262 - y2_output_root_mean_squared_error: 13.3740 - y3_output_root_mean_squared_error: 14.3295 - val_loss: 1717.5355 - val_y1_output_loss: 484.1941 - val_y2_output_loss: 269.0468 - val_y3_output_loss: 964.2952 - val_y1_output_root_mean_squared_error: 22.0044 - val_y2_output_root_mean_squared_error: 16.4026 - val_y3_output_root_mean_squared_error: 31.0531 - 26s/epoch - 6ms/step
# Epoch 56/1000
# 4666/4666 - 26s - loss: 1227.0060 - y1_output_loss: 844.1658 - y2_output_loss: 178.2107 - y3_output_loss: 204.6315 - y1_output_root_mean_squared_error: 29.0545 - y2_output_root_mean_squared_error: 13.3496 - y3_output_root_mean_squared_error: 14.3049 - val_loss: 1595.4557 - val_y1_output_loss: 492.2920 - val_y2_output_loss: 267.6216 - val_y3_output_loss: 835.5430 - val_y1_output_root_mean_squared_error: 22.1877 - val_y2_output_root_mean_squared_error: 16.3591 - val_y3_output_root_mean_squared_error: 28.9058 - 26s/epoch - 6ms/step
# Epoch 57/1000
# 4666/4666 - 26s - loss: 1221.8180 - y1_output_loss: 839.9928 - y2_output_loss: 177.0326 - y3_output_loss: 204.7915 - y1_output_root_mean_squared_error: 28.9826 - y2_output_root_mean_squared_error: 13.3054 - y3_output_root_mean_squared_error: 14.3105 - val_loss: 1602.5748 - val_y1_output_loss: 481.7256 - val_y2_output_loss: 258.7524 - val_y3_output_loss: 862.0988 - val_y1_output_root_mean_squared_error: 21.9482 - val_y2_output_root_mean_squared_error: 16.0858 - val_y3_output_root_mean_squared_error: 29.3615 - 26s/epoch - 6ms/step
# Epoch 58/1000
# 4666/4666 - 28s - loss: 1216.1338 - y1_output_loss: 835.8400 - y2_output_loss: 176.2961 - y3_output_loss: 204.0012 - y1_output_root_mean_squared_error: 28.9109 - y2_output_root_mean_squared_error: 13.2777 - y3_output_root_mean_squared_error: 14.2829 - val_loss: 1821.4894 - val_y1_output_loss: 474.4857 - val_y2_output_loss: 266.7953 - val_y3_output_loss: 1080.2063 - val_y1_output_root_mean_squared_error: 21.7827 - val_y2_output_root_mean_squared_error: 16.3339 - val_y3_output_root_mean_squared_error: 32.8665 - 28s/epoch - 6ms/step
# Epoch 59/1000
# 4666/4666 - 27s - loss: 1211.4182 - y1_output_loss: 831.6407 - y2_output_loss: 175.5338 - y3_output_loss: 204.2436 - y1_output_root_mean_squared_error: 28.8382 - y2_output_root_mean_squared_error: 13.2489 - y3_output_root_mean_squared_error: 14.2914 - val_loss: 1818.1123 - val_y1_output_loss: 470.7087 - val_y2_output_loss: 253.8752 - val_y3_output_loss: 1093.5302 - val_y1_output_root_mean_squared_error: 21.6958 - val_y2_output_root_mean_squared_error: 15.9335 - val_y3_output_root_mean_squared_error: 33.0686 - 27s/epoch - 6ms/step
# Epoch 60/1000
# 4666/4666 - 26s - loss: 1206.7073 - y1_output_loss: 828.2172 - y2_output_loss: 174.7082 - y3_output_loss: 203.7816 - y1_output_root_mean_squared_error: 28.7788 - y2_output_root_mean_squared_error: 13.2177 - y3_output_root_mean_squared_error: 14.2752 - val_loss: 1581.7360 - val_y1_output_loss: 463.2064 - val_y2_output_loss: 262.1413 - val_y3_output_loss: 856.3879 - val_y1_output_root_mean_squared_error: 21.5222 - val_y2_output_root_mean_squared_error: 16.1908 - val_y3_output_root_mean_squared_error: 29.2641 - 26s/epoch - 6ms/step
# Epoch 61/1000
# 4666/4666 - 27s - loss: 1199.8524 - y1_output_loss: 822.2259 - y2_output_loss: 174.0325 - y3_output_loss: 203.5950 - y1_output_root_mean_squared_error: 28.6745 - y2_output_root_mean_squared_error: 13.1921 - y3_output_root_mean_squared_error: 14.2687 - val_loss: 1683.4028 - val_y1_output_loss: 458.8870 - val_y2_output_loss: 251.2162 - val_y3_output_loss: 973.3005 - val_y1_output_root_mean_squared_error: 21.4216 - val_y2_output_root_mean_squared_error: 15.8498 - val_y3_output_root_mean_squared_error: 31.1978 - 27s/epoch - 6ms/step
# Epoch 62/1000
# 4666/4666 - 26s - loss: 1194.6932 - y1_output_loss: 818.8998 - y2_output_loss: 173.2222 - y3_output_loss: 202.5744 - y1_output_root_mean_squared_error: 28.6164 - y2_output_root_mean_squared_error: 13.1614 - y3_output_root_mean_squared_error: 14.2329 - val_loss: 1811.9764 - val_y1_output_loss: 466.8377 - val_y2_output_loss: 250.7229 - val_y3_output_loss: 1094.4155 - val_y1_output_root_mean_squared_error: 21.6064 - val_y2_output_root_mean_squared_error: 15.8342 - val_y3_output_root_mean_squared_error: 33.0820 - 26s/epoch - 5ms/step
# Epoch 63/1000
# 4666/4666 - 26s - loss: 1189.5149 - y1_output_loss: 815.1059 - y2_output_loss: 172.2298 - y3_output_loss: 202.1810 - y1_output_root_mean_squared_error: 28.5501 - y2_output_root_mean_squared_error: 13.1236 - y3_output_root_mean_squared_error: 14.2190 - val_loss: 1683.9631 - val_y1_output_loss: 455.5917 - val_y2_output_loss: 243.4094 - val_y3_output_loss: 984.9624 - val_y1_output_root_mean_squared_error: 21.3446 - val_y2_output_root_mean_squared_error: 15.6016 - val_y3_output_root_mean_squared_error: 31.3841 - 26s/epoch - 6ms/step
# Epoch 64/1000
# 4666/4666 - 26s - loss: 1183.3933 - y1_output_loss: 810.0005 - y2_output_loss: 171.5602 - y3_output_loss: 201.8335 - y1_output_root_mean_squared_error: 28.4605 - y2_output_root_mean_squared_error: 13.0981 - y3_output_root_mean_squared_error: 14.2068 - val_loss: 1603.9407 - val_y1_output_loss: 458.2307 - val_y2_output_loss: 247.5841 - val_y3_output_loss: 898.1263 - val_y1_output_root_mean_squared_error: 21.4063 - val_y2_output_root_mean_squared_error: 15.7348 - val_y3_output_root_mean_squared_error: 29.9688 - 26s/epoch - 6ms/step
# Epoch 65/1000
# 4666/4666 - 29s - loss: 1179.2572 - y1_output_loss: 806.8492 - y2_output_loss: 171.0246 - y3_output_loss: 201.3836 - y1_output_root_mean_squared_error: 28.4051 - y2_output_root_mean_squared_error: 13.0776 - y3_output_root_mean_squared_error: 14.1910 - val_loss: 1606.8618 - val_y1_output_loss: 448.1133 - val_y2_output_loss: 242.8686 - val_y3_output_loss: 915.8804 - val_y1_output_root_mean_squared_error: 21.1687 - val_y2_output_root_mean_squared_error: 15.5842 - val_y3_output_root_mean_squared_error: 30.2635 - 29s/epoch - 6ms/step
# Epoch 66/1000
# 4666/4666 - 27s - loss: 1174.5349 - y1_output_loss: 803.0743 - y2_output_loss: 170.1846 - y3_output_loss: 201.2769 - y1_output_root_mean_squared_error: 28.3386 - y2_output_root_mean_squared_error: 13.0455 - y3_output_root_mean_squared_error: 14.1872 - val_loss: 1537.0660 - val_y1_output_loss: 450.1058 - val_y2_output_loss: 244.9118 - val_y3_output_loss: 842.0473 - val_y1_output_root_mean_squared_error: 21.2157 - val_y2_output_root_mean_squared_error: 15.6497 - val_y3_output_root_mean_squared_error: 29.0181 - 27s/epoch - 6ms/step
# Epoch 67/1000
# 4666/4666 - 28s - loss: 1168.2859 - y1_output_loss: 798.5244 - y2_output_loss: 169.0946 - y3_output_loss: 200.6657 - y1_output_root_mean_squared_error: 28.2582 - y2_output_root_mean_squared_error: 13.0036 - y3_output_root_mean_squared_error: 14.1657 - val_loss: 1550.6648 - val_y1_output_loss: 448.3258 - val_y2_output_loss: 245.6827 - val_y3_output_loss: 856.6554 - val_y1_output_root_mean_squared_error: 21.1737 - val_y2_output_root_mean_squared_error: 15.6743 - val_y3_output_root_mean_squared_error: 29.2687 - 28s/epoch - 6ms/step
# Epoch 68/1000
# 4666/4666 - 30s - loss: 1165.4872 - y1_output_loss: 796.1219 - y2_output_loss: 168.6526 - y3_output_loss: 200.7113 - y1_output_root_mean_squared_error: 28.2156 - y2_output_root_mean_squared_error: 12.9866 - y3_output_root_mean_squared_error: 14.1673 - val_loss: 1662.0056 - val_y1_output_loss: 440.1364 - val_y2_output_loss: 228.2309 - val_y3_output_loss: 993.6385 - val_y1_output_root_mean_squared_error: 20.9794 - val_y2_output_root_mean_squared_error: 15.1073 - val_y3_output_root_mean_squared_error: 31.5220 - 30s/epoch - 6ms/step
# Epoch 69/1000
# 4666/4666 - 30s - loss: 1159.0532 - y1_output_loss: 791.1868 - y2_output_loss: 168.1168 - y3_output_loss: 199.7495 - y1_output_root_mean_squared_error: 28.1280 - y2_output_root_mean_squared_error: 12.9660 - y3_output_root_mean_squared_error: 14.1333 - val_loss: 1623.8157 - val_y1_output_loss: 437.1177 - val_y2_output_loss: 239.1047 - val_y3_output_loss: 947.5929 - val_y1_output_root_mean_squared_error: 20.9074 - val_y2_output_root_mean_squared_error: 15.4630 - val_y3_output_root_mean_squared_error: 30.7830 - 30s/epoch - 6ms/step
# Epoch 70/1000
# 4666/4666 - 29s - loss: 1154.8218 - y1_output_loss: 787.4431 - y2_output_loss: 167.4982 - y3_output_loss: 199.8799 - y1_output_root_mean_squared_error: 28.0614 - y2_output_root_mean_squared_error: 12.9421 - y3_output_root_mean_squared_error: 14.1379 - val_loss: 1435.7394 - val_y1_output_loss: 438.7580 - val_y2_output_loss: 239.8198 - val_y3_output_loss: 757.1602 - val_y1_output_root_mean_squared_error: 20.9466 - val_y2_output_root_mean_squared_error: 15.4861 - val_y3_output_root_mean_squared_error: 27.5165 - 29s/epoch - 6ms/step
# Epoch 71/1000
# 4666/4666 - 28s - loss: 1149.4530 - y1_output_loss: 783.8722 - y2_output_loss: 166.4048 - y3_output_loss: 199.1739 - y1_output_root_mean_squared_error: 27.9977 - y2_output_root_mean_squared_error: 12.8998 - y3_output_root_mean_squared_error: 14.1129 - val_loss: 1829.8123 - val_y1_output_loss: 431.4835 - val_y2_output_loss: 213.3450 - val_y3_output_loss: 1184.9854 - val_y1_output_root_mean_squared_error: 20.7722 - val_y2_output_root_mean_squared_error: 14.6063 - val_y3_output_root_mean_squared_error: 34.4236 - 28s/epoch - 6ms/step
# Epoch 72/1000
# 4666/4666 - 27s - loss: 1145.0071 - y1_output_loss: 780.0102 - y2_output_loss: 166.4783 - y3_output_loss: 198.5175 - y1_output_root_mean_squared_error: 27.9287 - y2_output_root_mean_squared_error: 12.9026 - y3_output_root_mean_squared_error: 14.0896 - val_loss: 1658.1396 - val_y1_output_loss: 427.5117 - val_y2_output_loss: 232.5192 - val_y3_output_loss: 998.1096 - val_y1_output_root_mean_squared_error: 20.6764 - val_y2_output_root_mean_squared_error: 15.2486 - val_y3_output_root_mean_squared_error: 31.5929 - 27s/epoch - 6ms/step
# Epoch 73/1000
# 4666/4666 - 28s - loss: 1141.0354 - y1_output_loss: 776.4490 - y2_output_loss: 165.9046 - y3_output_loss: 198.6852 - y1_output_root_mean_squared_error: 27.8648 - y2_output_root_mean_squared_error: 12.8804 - y3_output_root_mean_squared_error: 14.0956 - val_loss: 1574.3683 - val_y1_output_loss: 412.3182 - val_y2_output_loss: 224.8947 - val_y3_output_loss: 937.1545 - val_y1_output_root_mean_squared_error: 20.3056 - val_y2_output_root_mean_squared_error: 14.9965 - val_y3_output_root_mean_squared_error: 30.6130 - 28s/epoch - 6ms/step
# Epoch 74/1000
# 4666/4666 - 26s - loss: 1137.0005 - y1_output_loss: 773.5865 - y2_output_loss: 165.3390 - y3_output_loss: 198.0741 - y1_output_root_mean_squared_error: 27.8134 - y2_output_root_mean_squared_error: 12.8584 - y3_output_root_mean_squared_error: 14.0739 - val_loss: 1693.3719 - val_y1_output_loss: 420.6566 - val_y2_output_loss: 231.2965 - val_y3_output_loss: 1041.4182 - val_y1_output_root_mean_squared_error: 20.5099 - val_y2_output_root_mean_squared_error: 15.2084 - val_y3_output_root_mean_squared_error: 32.2710 - 26s/epoch - 6ms/step
# Epoch 75/1000
# 4666/4666 - 26s - loss: 1131.9590 - y1_output_loss: 769.6179 - y2_output_loss: 164.6019 - y3_output_loss: 197.7374 - y1_output_root_mean_squared_error: 27.7420 - y2_output_root_mean_squared_error: 12.8297 - y3_output_root_mean_squared_error: 14.0619 - val_loss: 1658.6550 - val_y1_output_loss: 417.6953 - val_y2_output_loss: 225.6525 - val_y3_output_loss: 1015.3059 - val_y1_output_root_mean_squared_error: 20.4376 - val_y2_output_root_mean_squared_error: 15.0217 - val_y3_output_root_mean_squared_error: 31.8639 - 26s/epoch - 6ms/step
# Epoch 76/1000
# 4666/4666 - 29s - loss: 1127.8857 - y1_output_loss: 766.7277 - y2_output_loss: 163.7592 - y3_output_loss: 197.3978 - y1_output_root_mean_squared_error: 27.6898 - y2_output_root_mean_squared_error: 12.7968 - y3_output_root_mean_squared_error: 14.0498 - val_loss: 1661.8185 - val_y1_output_loss: 411.7910 - val_y2_output_loss: 218.7709 - val_y3_output_loss: 1031.2561 - val_y1_output_root_mean_squared_error: 20.2926 - val_y2_output_root_mean_squared_error: 14.7909 - val_y3_output_root_mean_squared_error: 32.1132 - 29s/epoch - 6ms/step
# Epoch 77/1000
# 4666/4666 - 29s - loss: 1122.8737 - y1_output_loss: 762.6773 - y2_output_loss: 163.1376 - y3_output_loss: 197.0568 - y1_output_root_mean_squared_error: 27.6166 - y2_output_root_mean_squared_error: 12.7725 - y3_output_root_mean_squared_error: 14.0377 - val_loss: 1550.4567 - val_y1_output_loss: 411.4491 - val_y2_output_loss: 216.4949 - val_y3_output_loss: 922.5123 - val_y1_output_root_mean_squared_error: 20.2842 - val_y2_output_root_mean_squared_error: 14.7138 - val_y3_output_root_mean_squared_error: 30.3729 - 29s/epoch - 6ms/step
# Epoch 78/1000
# 4666/4666 - 27s - loss: 1119.4194 - y1_output_loss: 759.4147 - y2_output_loss: 162.9711 - y3_output_loss: 197.0346 - y1_output_root_mean_squared_error: 27.5575 - y2_output_root_mean_squared_error: 12.7660 - y3_output_root_mean_squared_error: 14.0369 - val_loss: 1518.5085 - val_y1_output_loss: 410.0333 - val_y2_output_loss: 209.1420 - val_y3_output_loss: 899.3338 - val_y1_output_root_mean_squared_error: 20.2493 - val_y2_output_root_mean_squared_error: 14.4617 - val_y3_output_root_mean_squared_error: 29.9889 - 27s/epoch - 6ms/step
# Epoch 79/1000
# 4666/4666 - 26s - loss: 1115.9187 - y1_output_loss: 757.1404 - y2_output_loss: 162.1861 - y3_output_loss: 196.5896 - y1_output_root_mean_squared_error: 27.5162 - y2_output_root_mean_squared_error: 12.7352 - y3_output_root_mean_squared_error: 14.0210 - val_loss: 1550.3823 - val_y1_output_loss: 409.3839 - val_y2_output_loss: 210.8484 - val_y3_output_loss: 930.1514 - val_y1_output_root_mean_squared_error: 20.2332 - val_y2_output_root_mean_squared_error: 14.5206 - val_y3_output_root_mean_squared_error: 30.4984 - 26s/epoch - 5ms/step
# Epoch 80/1000
# 4666/4666 - 26s - loss: 1111.5867 - y1_output_loss: 753.6609 - y2_output_loss: 161.3881 - y3_output_loss: 196.5341 - y1_output_root_mean_squared_error: 27.4529 - y2_output_root_mean_squared_error: 12.7039 - y3_output_root_mean_squared_error: 14.0191 - val_loss: 1537.8334 - val_y1_output_loss: 400.9915 - val_y2_output_loss: 212.0049 - val_y3_output_loss: 924.8373 - val_y1_output_root_mean_squared_error: 20.0248 - val_y2_output_root_mean_squared_error: 14.5604 - val_y3_output_root_mean_squared_error: 30.4111 - 26s/epoch - 6ms/step
# Epoch 81/1000
# 4666/4666 - 25s - loss: 1106.5654 - y1_output_loss: 749.3620 - y2_output_loss: 161.0401 - y3_output_loss: 196.1655 - y1_output_root_mean_squared_error: 27.3745 - y2_output_root_mean_squared_error: 12.6902 - y3_output_root_mean_squared_error: 14.0059 - val_loss: 1512.5720 - val_y1_output_loss: 401.7720 - val_y2_output_loss: 205.3287 - val_y3_output_loss: 905.4717 - val_y1_output_root_mean_squared_error: 20.0443 - val_y2_output_root_mean_squared_error: 14.3293 - val_y3_output_root_mean_squared_error: 30.0911 - 25s/epoch - 5ms/step
# Epoch 82/1000
# 4666/4666 - 26s - loss: 1102.2646 - y1_output_loss: 745.5421 - y2_output_loss: 160.9680 - y3_output_loss: 195.7533 - y1_output_root_mean_squared_error: 27.3046 - y2_output_root_mean_squared_error: 12.6873 - y3_output_root_mean_squared_error: 13.9912 - val_loss: 1610.5310 - val_y1_output_loss: 400.6909 - val_y2_output_loss: 207.5697 - val_y3_output_loss: 1002.2701 - val_y1_output_root_mean_squared_error: 20.0173 - val_y2_output_root_mean_squared_error: 14.4073 - val_y3_output_root_mean_squared_error: 31.6586 - 26s/epoch - 6ms/step
# Epoch 83/1000
# 4666/4666 - 25s - loss: 1099.4888 - y1_output_loss: 743.8577 - y2_output_loss: 160.2500 - y3_output_loss: 195.3794 - y1_output_root_mean_squared_error: 27.2738 - y2_output_root_mean_squared_error: 12.6590 - y3_output_root_mean_squared_error: 13.9778 - val_loss: 1338.5100 - val_y1_output_loss: 404.0367 - val_y2_output_loss: 233.6493 - val_y3_output_loss: 700.8243 - val_y1_output_root_mean_squared_error: 20.1007 - val_y2_output_root_mean_squared_error: 15.2856 - val_y3_output_root_mean_squared_error: 26.4731 - 25s/epoch - 5ms/step
# Epoch 84/1000
# 4666/4666 - 25s - loss: 1095.2203 - y1_output_loss: 740.4438 - y2_output_loss: 159.5287 - y3_output_loss: 195.2496 - y1_output_root_mean_squared_error: 27.2111 - y2_output_root_mean_squared_error: 12.6305 - y3_output_root_mean_squared_error: 13.9732 - val_loss: 1564.1998 - val_y1_output_loss: 387.6434 - val_y2_output_loss: 212.8884 - val_y3_output_loss: 963.6673 - val_y1_output_root_mean_squared_error: 19.6887 - val_y2_output_root_mean_squared_error: 14.5907 - val_y3_output_root_mean_squared_error: 31.0430 - 25s/epoch - 5ms/step
# Epoch 85/1000
# 4666/4666 - 26s - loss: 1091.4691 - y1_output_loss: 737.3475 - y2_output_loss: 159.1537 - y3_output_loss: 194.9663 - y1_output_root_mean_squared_error: 27.1541 - y2_output_root_mean_squared_error: 12.6156 - y3_output_root_mean_squared_error: 13.9630 - val_loss: 1568.6365 - val_y1_output_loss: 393.9525 - val_y2_output_loss: 202.4901 - val_y3_output_loss: 972.1934 - val_y1_output_root_mean_squared_error: 19.8482 - val_y2_output_root_mean_squared_error: 14.2299 - val_y3_output_root_mean_squared_error: 31.1800 - 26s/epoch - 6ms/step
# Epoch 86/1000
# 4666/4666 - 26s - loss: 1088.7831 - y1_output_loss: 734.7508 - y2_output_loss: 158.8843 - y3_output_loss: 195.1473 - y1_output_root_mean_squared_error: 27.1063 - y2_output_root_mean_squared_error: 12.6049 - y3_output_root_mean_squared_error: 13.9695 - val_loss: 1549.9674 - val_y1_output_loss: 380.1949 - val_y2_output_loss: 196.4656 - val_y3_output_loss: 973.3085 - val_y1_output_root_mean_squared_error: 19.4986 - val_y2_output_root_mean_squared_error: 14.0166 - val_y3_output_root_mean_squared_error: 31.1979 - 26s/epoch - 6ms/step
# Epoch 87/1000
# 4666/4666 - 26s - loss: 1084.1460 - y1_output_loss: 731.4467 - y2_output_loss: 158.2090 - y3_output_loss: 194.4910 - y1_output_root_mean_squared_error: 27.0453 - y2_output_root_mean_squared_error: 12.5781 - y3_output_root_mean_squared_error: 13.9460 - val_loss: 1455.9299 - val_y1_output_loss: 382.9138 - val_y2_output_loss: 204.8052 - val_y3_output_loss: 868.2108 - val_y1_output_root_mean_squared_error: 19.5682 - val_y2_output_root_mean_squared_error: 14.3110 - val_y3_output_root_mean_squared_error: 29.4654 - 26s/epoch - 5ms/step
# Epoch 88/1000
# ...
# Epoch 972/1000
# 4666/4666 - 24s - loss: 616.6851 - y1_output_loss: 366.4063 - y2_output_loss: 105.7103 - y3_output_loss: 144.5681 - y1_output_root_mean_squared_error: 19.1417 - y2_output_root_mean_squared_error: 10.2816 - y3_output_root_mean_squared_error: 12.0236 - val_loss: 1168.8892 - val_y1_output_loss: 125.2078 - val_y2_output_loss: 158.8612 - val_y3_output_loss: 884.8199 - val_y1_output_root_mean_squared_error: 11.1896 - val_y2_output_root_mean_squared_error: 12.6040 - val_y3_output_root_mean_squared_error: 29.7459 - 24s/epoch - 5ms/step
# Epoch 973/1000
# 4666/4666 - 24s - loss: 618.1908 - y1_output_loss: 367.5422 - y2_output_loss: 105.8528 - y3_output_loss: 144.7963 - y1_output_root_mean_squared_error: 19.1714 - y2_output_root_mean_squared_error: 10.2885 - y3_output_root_mean_squared_error: 12.0331 - val_loss: 1176.0175 - val_y1_output_loss: 126.5047 - val_y2_output_loss: 113.7439 - val_y3_output_loss: 935.7689 - val_y1_output_root_mean_squared_error: 11.2474 - val_y2_output_root_mean_squared_error: 10.6651 - val_y3_output_root_mean_squared_error: 30.5903 - 24s/epoch - 5ms/step
# Epoch 974/1000
# 4666/4666 - 24s - loss: 616.6369 - y1_output_loss: 366.4410 - y2_output_loss: 105.7098 - y3_output_loss: 144.4865 - y1_output_root_mean_squared_error: 19.1426 - y2_output_root_mean_squared_error: 10.2815 - y3_output_root_mean_squared_error: 12.0203 - val_loss: 1116.9993 - val_y1_output_loss: 102.4146 - val_y2_output_loss: 156.6572 - val_y3_output_loss: 857.9269 - val_y1_output_root_mean_squared_error: 10.1200 - val_y2_output_root_mean_squared_error: 12.5163 - val_y3_output_root_mean_squared_error: 29.2904 - 24s/epoch - 5ms/step
# Epoch 975/1000
# 4666/4666 - 24s - loss: 616.7452 - y1_output_loss: 366.7913 - y2_output_loss: 105.5825 - y3_output_loss: 144.3716 - y1_output_root_mean_squared_error: 19.1518 - y2_output_root_mean_squared_error: 10.2753 - y3_output_root_mean_squared_error: 12.0155 - val_loss: 1137.5094 - val_y1_output_loss: 108.4524 - val_y2_output_loss: 144.0909 - val_y3_output_loss: 884.9656 - val_y1_output_root_mean_squared_error: 10.4140 - val_y2_output_root_mean_squared_error: 12.0038 - val_y3_output_root_mean_squared_error: 29.7484 - 24s/epoch - 5ms/step
# Epoch 976/1000
# 4666/4666 - 24s - loss: 616.7429 - y1_output_loss: 366.8645 - y2_output_loss: 105.5888 - y3_output_loss: 144.2908 - y1_output_root_mean_squared_error: 19.1537 - y2_output_root_mean_squared_error: 10.2756 - y3_output_root_mean_squared_error: 12.0121 - val_loss: 1137.9235 - val_y1_output_loss: 115.1042 - val_y2_output_loss: 156.1250 - val_y3_output_loss: 866.6941 - val_y1_output_root_mean_squared_error: 10.7287 - val_y2_output_root_mean_squared_error: 12.4950 - val_y3_output_root_mean_squared_error: 29.4397 - 24s/epoch - 5ms/step
# Epoch 977/1000
# 4666/4666 - 24s - loss: 616.9262 - y1_output_loss: 367.3454 - y2_output_loss: 105.3341 - y3_output_loss: 144.2454 - y1_output_root_mean_squared_error: 19.1663 - y2_output_root_mean_squared_error: 10.2632 - y3_output_root_mean_squared_error: 12.0102 - val_loss: 1182.2227 - val_y1_output_loss: 110.6725 - val_y2_output_loss: 167.1343 - val_y3_output_loss: 904.4168 - val_y1_output_root_mean_squared_error: 10.5201 - val_y2_output_root_mean_squared_error: 12.9280 - val_y3_output_root_mean_squared_error: 30.0735 - 24s/epoch - 5ms/step
# Epoch 978/1000
# 4666/4666 - 24s - loss: 616.2582 - y1_output_loss: 366.6889 - y2_output_loss: 105.3787 - y3_output_loss: 144.1897 - y1_output_root_mean_squared_error: 19.1491 - y2_output_root_mean_squared_error: 10.2654 - y3_output_root_mean_squared_error: 12.0079 - val_loss: 1150.4625 - val_y1_output_loss: 106.5896 - val_y2_output_loss: 141.4795 - val_y3_output_loss: 902.3939 - val_y1_output_root_mean_squared_error: 10.3242 - val_y2_output_root_mean_squared_error: 11.8945 - val_y3_output_root_mean_squared_error: 30.0399 - 24s/epoch - 5ms/step
# Epoch 979/1000
# 4666/4666 - 25s - loss: 617.0295 - y1_output_loss: 367.0374 - y2_output_loss: 105.6609 - y3_output_loss: 144.3299 - y1_output_root_mean_squared_error: 19.1582 - y2_output_root_mean_squared_error: 10.2791 - y3_output_root_mean_squared_error: 12.0137 - val_loss: 1056.4728 - val_y1_output_loss: 106.4427 - val_y2_output_loss: 177.8991 - val_y3_output_loss: 772.1301 - val_y1_output_root_mean_squared_error: 10.3171 - val_y2_output_root_mean_squared_error: 13.3379 - val_y3_output_root_mean_squared_error: 27.7872 - 25s/epoch - 5ms/step
# Epoch 980/1000
# 4666/4666 - 24s - loss: 616.8210 - y1_output_loss: 367.0482 - y2_output_loss: 105.4961 - y3_output_loss: 144.2778 - y1_output_root_mean_squared_error: 19.1585 - y2_output_root_mean_squared_error: 10.2711 - y3_output_root_mean_squared_error: 12.0116 - val_loss: 995.9476 - val_y1_output_loss: 94.6068 - val_y2_output_loss: 118.0186 - val_y3_output_loss: 783.3223 - val_y1_output_root_mean_squared_error: 9.7266 - val_y2_output_root_mean_squared_error: 10.8636 - val_y3_output_root_mean_squared_error: 27.9879 - 24s/epoch - 5ms/step
# Epoch 981/1000
# 4666/4666 - 24s - loss: 616.7001 - y1_output_loss: 367.1747 - y2_output_loss: 105.5776 - y3_output_loss: 143.9477 - y1_output_root_mean_squared_error: 19.1618 - y2_output_root_mean_squared_error: 10.2751 - y3_output_root_mean_squared_error: 11.9978 - val_loss: 1096.7091 - val_y1_output_loss: 100.4773 - val_y2_output_loss: 153.1744 - val_y3_output_loss: 843.0565 - val_y1_output_root_mean_squared_error: 10.0238 - val_y2_output_root_mean_squared_error: 12.3764 - val_y3_output_root_mean_squared_error: 29.0354 - 24s/epoch - 5ms/step
# Epoch 982/1000
# 4666/4666 - 24s - loss: 616.6044 - y1_output_loss: 366.4550 - y2_output_loss: 105.6642 - y3_output_loss: 144.4860 - y1_output_root_mean_squared_error: 19.1430 - y2_output_root_mean_squared_error: 10.2793 - y3_output_root_mean_squared_error: 12.0202 - val_loss: 1191.4417 - val_y1_output_loss: 96.8902 - val_y2_output_loss: 171.4763 - val_y3_output_loss: 923.0749 - val_y1_output_root_mean_squared_error: 9.8433 - val_y2_output_root_mean_squared_error: 13.0949 - val_y3_output_root_mean_squared_error: 30.3821 - 24s/epoch - 5ms/step
# Epoch 983/1000
# 4666/4666 - 24s - loss: 616.7374 - y1_output_loss: 366.8531 - y2_output_loss: 105.4731 - y3_output_loss: 144.4113 - y1_output_root_mean_squared_error: 19.1534 - y2_output_root_mean_squared_error: 10.2700 - y3_output_root_mean_squared_error: 12.0171 - val_loss: 1104.2191 - val_y1_output_loss: 110.2196 - val_y2_output_loss: 142.7376 - val_y3_output_loss: 851.2628 - val_y1_output_root_mean_squared_error: 10.4986 - val_y2_output_root_mean_squared_error: 11.9473 - val_y3_output_root_mean_squared_error: 29.1764 - 24s/epoch - 5ms/step
# Epoch 984/1000
# 4666/4666 - 24s - loss: 616.1097 - y1_output_loss: 366.4785 - y2_output_loss: 105.4049 - y3_output_loss: 144.2263 - y1_output_root_mean_squared_error: 19.1436 - y2_output_root_mean_squared_error: 10.2667 - y3_output_root_mean_squared_error: 12.0094 - val_loss: 1051.5464 - val_y1_output_loss: 101.7766 - val_y2_output_loss: 169.6744 - val_y3_output_loss: 780.0949 - val_y1_output_root_mean_squared_error: 10.0884 - val_y2_output_root_mean_squared_error: 13.0259 - val_y3_output_root_mean_squared_error: 27.9302 - 24s/epoch - 5ms/step
# Epoch 985/1000
# 4666/4666 - 24s - loss: 616.6506 - y1_output_loss: 366.9195 - y2_output_loss: 105.4559 - y3_output_loss: 144.2751 - y1_output_root_mean_squared_error: 19.1551 - y2_output_root_mean_squared_error: 10.2692 - y3_output_root_mean_squared_error: 12.0115 - val_loss: 1291.9071 - val_y1_output_loss: 109.5320 - val_y2_output_loss: 138.5272 - val_y3_output_loss: 1043.8483 - val_y1_output_root_mean_squared_error: 10.4658 - val_y2_output_root_mean_squared_error: 11.7698 - val_y3_output_root_mean_squared_error: 32.3086 - 24s/epoch - 5ms/step
# Epoch 986/1000
# 4666/4666 - 24s - loss: 617.0744 - y1_output_loss: 366.7396 - y2_output_loss: 105.8939 - y3_output_loss: 144.4404 - y1_output_root_mean_squared_error: 19.1504 - y2_output_root_mean_squared_error: 10.2905 - y3_output_root_mean_squared_error: 12.0183 - val_loss: 1057.5594 - val_y1_output_loss: 110.8854 - val_y2_output_loss: 164.7908 - val_y3_output_loss: 781.8836 - val_y1_output_root_mean_squared_error: 10.5302 - val_y2_output_root_mean_squared_error: 12.8371 - val_y3_output_root_mean_squared_error: 27.9622 - 24s/epoch - 5ms/step
# Epoch 987/1000
# 4666/4666 - 24s - loss: 616.4167 - y1_output_loss: 366.4647 - y2_output_loss: 105.7320 - y3_output_loss: 144.2199 - y1_output_root_mean_squared_error: 19.1433 - y2_output_root_mean_squared_error: 10.2826 - y3_output_root_mean_squared_error: 12.0092 - val_loss: 1081.9694 - val_y1_output_loss: 110.7708 - val_y2_output_loss: 158.9315 - val_y3_output_loss: 812.2675 - val_y1_output_root_mean_squared_error: 10.5248 - val_y2_output_root_mean_squared_error: 12.6068 - val_y3_output_root_mean_squared_error: 28.5003 - 24s/epoch - 5ms/step
# Epoch 988/1000
# 4666/4666 - 25s - loss: 616.1371 - y1_output_loss: 366.5449 - y2_output_loss: 105.3771 - y3_output_loss: 144.2161 - y1_output_root_mean_squared_error: 19.1454 - y2_output_root_mean_squared_error: 10.2653 - y3_output_root_mean_squared_error: 12.0090 - val_loss: 1165.1343 - val_y1_output_loss: 114.6575 - val_y2_output_loss: 109.8960 - val_y3_output_loss: 940.5806 - val_y1_output_root_mean_squared_error: 10.7078 - val_y2_output_root_mean_squared_error: 10.4831 - val_y3_output_root_mean_squared_error: 30.6689 - 25s/epoch - 5ms/step
# Epoch 989/1000
# 4666/4666 - 24s - loss: 615.9100 - y1_output_loss: 366.3952 - y2_output_loss: 105.4098 - y3_output_loss: 144.1050 - y1_output_root_mean_squared_error: 19.1415 - y2_output_root_mean_squared_error: 10.2669 - y3_output_root_mean_squared_error: 12.0044 - val_loss: 1154.8903 - val_y1_output_loss: 114.5322 - val_y2_output_loss: 143.9041 - val_y3_output_loss: 896.4534 - val_y1_output_root_mean_squared_error: 10.7020 - val_y2_output_root_mean_squared_error: 11.9960 - val_y3_output_root_mean_squared_error: 29.9408 - 24s/epoch - 5ms/step
# Epoch 990/1000
# 4666/4666 - 24s - loss: 616.8518 - y1_output_loss: 367.3897 - y2_output_loss: 105.4774 - y3_output_loss: 143.9843 - y1_output_root_mean_squared_error: 19.1674 - y2_output_root_mean_squared_error: 10.2702 - y3_output_root_mean_squared_error: 11.9993 - val_loss: 1173.6390 - val_y1_output_loss: 104.3889 - val_y2_output_loss: 191.9380 - val_y3_output_loss: 877.3109 - val_y1_output_root_mean_squared_error: 10.2171 - val_y2_output_root_mean_squared_error: 13.8542 - val_y3_output_root_mean_squared_error: 29.6194 - 24s/epoch - 5ms/step
# Epoch 991/1000
# 4666/4666 - 24s - loss: 616.3361 - y1_output_loss: 366.8361 - y2_output_loss: 105.6132 - y3_output_loss: 143.8872 - y1_output_root_mean_squared_error: 19.1530 - y2_output_root_mean_squared_error: 10.2768 - y3_output_root_mean_squared_error: 11.9953 - val_loss: 1189.0746 - val_y1_output_loss: 112.3653 - val_y2_output_loss: 129.0259 - val_y3_output_loss: 947.6841 - val_y1_output_root_mean_squared_error: 10.6003 - val_y2_output_root_mean_squared_error: 11.3590 - val_y3_output_root_mean_squared_error: 30.7845 - 24s/epoch - 5ms/step
# Epoch 992/1000
# 4666/4666 - 24s - loss: 616.0783 - y1_output_loss: 366.3637 - y2_output_loss: 105.5025 - y3_output_loss: 144.2114 - y1_output_root_mean_squared_error: 19.1406 - y2_output_root_mean_squared_error: 10.2714 - y3_output_root_mean_squared_error: 12.0088 - val_loss: 1081.2715 - val_y1_output_loss: 102.5016 - val_y2_output_loss: 162.2554 - val_y3_output_loss: 816.5142 - val_y1_output_root_mean_squared_error: 10.1243 - val_y2_output_root_mean_squared_error: 12.7380 - val_y3_output_root_mean_squared_error: 28.5747 - 24s/epoch - 5ms/step
# Epoch 993/1000
# 4666/4666 - 24s - loss: 616.2487 - y1_output_loss: 366.7943 - y2_output_loss: 105.4384 - y3_output_loss: 144.0153 - y1_output_root_mean_squared_error: 19.1519 - y2_output_root_mean_squared_error: 10.2683 - y3_output_root_mean_squared_error: 12.0006 - val_loss: 1219.2625 - val_y1_output_loss: 137.0098 - val_y2_output_loss: 136.9151 - val_y3_output_loss: 945.3375 - val_y1_output_root_mean_squared_error: 11.7051 - val_y2_output_root_mean_squared_error: 11.7011 - val_y3_output_root_mean_squared_error: 30.7463 - 24s/epoch - 5ms/step
# Epoch 994/1000
# 4666/4666 - 24s - loss: 616.0554 - y1_output_loss: 366.8274 - y2_output_loss: 105.3310 - y3_output_loss: 143.8975 - y1_output_root_mean_squared_error: 19.1527 - y2_output_root_mean_squared_error: 10.2631 - y3_output_root_mean_squared_error: 11.9957 - val_loss: 1095.0696 - val_y1_output_loss: 109.5403 - val_y2_output_loss: 148.2351 - val_y3_output_loss: 837.2946 - val_y1_output_root_mean_squared_error: 10.4661 - val_y2_output_root_mean_squared_error: 12.1752 - val_y3_output_root_mean_squared_error: 28.9360 - 24s/epoch - 5ms/step
# Epoch 995/1000
# 4666/4666 - 24s - loss: 616.8242 - y1_output_loss: 367.0728 - y2_output_loss: 105.7112 - y3_output_loss: 144.0413 - y1_output_root_mean_squared_error: 19.1591 - y2_output_root_mean_squared_error: 10.2816 - y3_output_root_mean_squared_error: 12.0017 - val_loss: 1009.0734 - val_y1_output_loss: 134.2685 - val_y2_output_loss: 103.2019 - val_y3_output_loss: 771.6031 - val_y1_output_root_mean_squared_error: 11.5874 - val_y2_output_root_mean_squared_error: 10.1588 - val_y3_output_root_mean_squared_error: 27.7777 - 24s/epoch - 5ms/step
# Epoch 996/1000
# 4666/4666 - 24s - loss: 615.4566 - y1_output_loss: 366.1063 - y2_output_loss: 105.3930 - y3_output_loss: 143.9566 - y1_output_root_mean_squared_error: 19.1339 - y2_output_root_mean_squared_error: 10.2661 - y3_output_root_mean_squared_error: 11.9982 - val_loss: 1221.7490 - val_y1_output_loss: 112.3298 - val_y2_output_loss: 149.0735 - val_y3_output_loss: 960.3450 - val_y1_output_root_mean_squared_error: 10.5986 - val_y2_output_root_mean_squared_error: 12.2096 - val_y3_output_root_mean_squared_error: 30.9894 - 24s/epoch - 5ms/step
# Epoch 997/1000
# 4666/4666 - 24s - loss: 615.9966 - y1_output_loss: 366.2294 - y2_output_loss: 105.5617 - y3_output_loss: 144.2057 - y1_output_root_mean_squared_error: 19.1371 - y2_output_root_mean_squared_error: 10.2743 - y3_output_root_mean_squared_error: 12.0086 - val_loss: 1125.1116 - val_y1_output_loss: 105.1984 - val_y2_output_loss: 116.5899 - val_y3_output_loss: 903.3230 - val_y1_output_root_mean_squared_error: 10.2566 - val_y2_output_root_mean_squared_error: 10.7977 - val_y3_output_root_mean_squared_error: 30.0553 - 24s/epoch - 5ms/step
# Epoch 998/1000
# 4666/4666 - 25s - loss: 616.1652 - y1_output_loss: 366.8000 - y2_output_loss: 105.5357 - y3_output_loss: 143.8292 - y1_output_root_mean_squared_error: 19.1520 - y2_output_root_mean_squared_error: 10.2731 - y3_output_root_mean_squared_error: 11.9929 - val_loss: 1222.0267 - val_y1_output_loss: 121.6572 - val_y2_output_loss: 161.5954 - val_y3_output_loss: 938.7758 - val_y1_output_root_mean_squared_error: 11.0298 - val_y2_output_root_mean_squared_error: 12.7120 - val_y3_output_root_mean_squared_error: 30.6394 - 25s/epoch - 5ms/step
# Epoch 999/1000
# 4666/4666 - 24s - loss: 615.3497 - y1_output_loss: 366.4326 - y2_output_loss: 105.1151 - y3_output_loss: 143.8013 - y1_output_root_mean_squared_error: 19.1424 - y2_output_root_mean_squared_error: 10.2526 - y3_output_root_mean_squared_error: 11.9917 - val_loss: 1203.2335 - val_y1_output_loss: 119.2841 - val_y2_output_loss: 161.9649 - val_y3_output_loss: 921.9839 - val_y1_output_root_mean_squared_error: 10.9217 - val_y2_output_root_mean_squared_error: 12.7265 - val_y3_output_root_mean_squared_error: 30.3642 - 24s/epoch - 5ms/step
# Epoch 1000/1000
# 4666/4666 - 24s - loss: 615.4605 - y1_output_loss: 366.6311 - y2_output_loss: 105.0242 - y3_output_loss: 143.8060 - y1_output_root_mean_squared_error: 19.1476 - y2_output_root_mean_squared_error: 10.2481 - y3_output_root_mean_squared_error: 11.9919 - val_loss: 1080.7056 - val_y1_output_loss: 117.6115 - val_y2_output_loss: 163.7152 - val_y3_output_loss: 799.3799 - val_y1_output_root_mean_squared_error: 10.8449 - val_y2_output_root_mean_squared_error: 12.7951 - val_y3_output_root_mean_squared_error: 28.2733 - 24s/epoch - 5ms/step

# %%
plot_history(history)

Y1_pred , Y2_pred, Y3_pred = model.predict(X_valid)
X_valid
# Out:
# 36450/36450 [==============================] - 29s 780us/step
# array([[-0.2863962 ,  0.33578501,  0.55414698],
#        [-0.91653291, -2.32526814, -0.14931547],
#        [ 1.29252844, -1.38489373,  0.6991253 ],
#        ...,
#        [-0.06257277,  0.46336362,  1.75999604],
#        [-0.61532321,  0.04696319, -0.21883651],
#        [-0.18946225, -0.58729254, -1.73777985]])

# %%
plt.scatter(y1_test, Y1_pred)
combined_array1 = np.column_stack((y1_test, Y1_pred))

# %%
combined_array1

plt.scatter(y2_test, Y2_pred)
combined_array2 = np.column_stack((y2_test, Y2_pred))

# %%
combined_array2

plt.scatter(y3_test, Y3_pred)
combined_array3 = np.column_stack((y3_test, Y3_pred))

# %%
combined_array3
# Out:
# array([[114.        , 122.60832214],
#        [ 17.        ,  70.85874939],
#        [ 37.        ,  68.02609253],
#        ...,
#        [  6.        ,  50.48288345],
#        [140.        , 151.70709229],
#        [123.        , 153.29544067]])

# %%
def scale_this_point(point_in_space):
    X , Y , Z =   point_in_space
    X_norm = (X - X_train_df.loc[:,'X'].mean()) / X_train_df.loc[:,'X'].std()
    Y_norm = (Y - X_train_df.loc[:,'Y'].mean())/ X_train_df.loc[:,'Y'].std()
    Z_norm = (Z - X_train_df.loc[:,'Z'].mean()) / X_train_df.loc[:,'Z'].std()
    
    return X_norm, Y_norm, Z_norm

point = np.array([7.0197861,  3.27338002, 9.94331352])

point_in_space_norm = scale_this_point(point)
print(point_in_space_norm)
point_in_space_norm[0]

#prediction on the point
NEW_point_to_predict = np.array([[point_in_space_norm[0], point_in_space_norm[1],point_in_space_norm[2]]])
Theta1, Theta2, Theta3 = model.predict(NEW_point_to_predict)
# Out:
# (1.9829295293883993, 1.373102177082806, 0.7085871098237017)
# 1/1 [==============================] - 0s 72ms/step

# %%
print(Theta1)
print(Theta2)
print(Theta3)
# Out:
# [[36.58993]]
# [[11.358237]]
# [[70.61282]]

# %%
import os

# Define the directory path
directory = r'C:\Majkel\Robotyka\PYTHON_TEST\MODEL_180_1_1000_prob'

# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Now save your model
model.save(os.path.join(directory, 'MODEL_180_1_1000_prob'))
# Out:
# INFO:tensorflow:Assets written to: C:\Majkel\Robotyka\PYTHON_TEST\MODEL_180_1_1000_prob\MODEL_180_1_1000_prob\assets
# INFO:tensorflow:Assets written to: C:\Majkel\Robotyka\PYTHON_TEST\MODEL_180_1_1000_prob\MODEL_180_1_1000_prob\assets
